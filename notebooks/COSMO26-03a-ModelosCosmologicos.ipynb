# %% [markdown]
# # Ejercicio 1. Evolución de las densidades ($\rho$, $\rho_c\,$, $\Omega$) con el factor de escala $a(t)$
# Considera un universo con $\Omega_m=0.3086$, $\Omega_\Lambda=0.6914$, $h=0.6777$ y $\Omega_r=4.17515\cdot10^5 h^2$.
# * Representa la evolución de $\rho_m$, $\rho_r$ y $\rho_\Lambda$ en función de $a(t)/a(t_0)$ en escala logarítmica.
# * Representa la evolución de $\rho_c$ en función de $a(t)/a(t_0)$.
# * Representa la evolución de $\Omega_r$, $\Omega_m$ y $\Omega_\Lambda$ en función de $a(t)/a(t_0)$ en escala logarítmica.

# %% [markdown]
# # Ejercicio 2. Evolución del factor de escala $a(t)$ con el tiempo

# %% [markdown]
# # Ejercicio 3. Tiempo de retroceso

# %% [markdown]
# # Ejercicio 4. Distancias cosmológicas

# %% [markdown]
# # Ejercicio 5. Distancias en universo plano, abierto y cerrado

# %% [markdown]
# # Ejercicio 6. Distancia de luminosidad $d_L(z)$ para distintos modelos cosmológicos

# %% [markdown]
# # Ejercicio 7. Magnitud bolométrica aparente $\mu(z)$
